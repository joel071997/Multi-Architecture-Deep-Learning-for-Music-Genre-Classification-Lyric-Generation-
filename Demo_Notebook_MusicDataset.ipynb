# %% [markdown]
# # Deep Learning Assignment 1 Demo Notebook Part 1
# ---
# ### Author : Joel Quadras (D22125093)

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Load Libraries

# %%
import gdown
import os,glob
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ### Load Test data and saved Models from the drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
url = "https://drive.google.com/drive/folders/1mrXxH6cFy3yUFYsXoYHLhNI0QevCvpn4?usp=sharing"
gdown.download_folder (url, quiet=True, use_cookies=False)
# Out:
# False

# %% [markdown]
# ### Test Data Preprocessing

# %%
# Loading the separate test dataset
df_full_test_data = pd.read_csv("/content/original_dataset/test.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-d8e1d9c05ee8> in <cell line: 2>()
#       1 # Loading the separate test dataset
# ----> 2 df_full_test_data = pd.read_csv("/content/original_dataset/test.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df_full_test_data.head()

# %%
import gdown
import os,glob
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import ast
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import Concatenate, Dense, LSTM, Input,GRU, concatenate,Dropout,LeakyReLU,SimpleRNN,Reshape
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Input,Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import one_hot
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Flatten
from keras.models import Model
import joblib
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC

# %%
# Load the test dataset
data = np.load('/content/drive/MyDrive/original_dataset/Task_1_model_weights/train_and_test_data.npz', allow_pickle = True)

# Get the arrays from the loaded data
X_test = data['X_test']
y_test = data['y_test']

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense

from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt

# %% [markdown]
# ## RNN Variants

# %% [markdown]
# ### SimpleRNN

# %%
from tensorflow.keras.layers import SimpleRNN, BatchNormalization, LeakyReLU, Flatten, Dense
from tensorflow.keras.models import Sequential

# %%
from keras.models import Sequential, load_model
import pickle
#saving model
rnn_model = load_model('/content/drive/MyDrive/original_dataset/Task_1_model_weights/rnn_model/rnn_model.h5')

# Load the history
with open('/content/drive/MyDrive/original_dataset/Task_1_model_weights/rnn_model/rnn_history.pkl', 'rb') as f:
    rnn_history = pickle.load(f)

# %%
# Convert the TF-IDF vectors to dense NumPy arrays
#X_test_array = X_test.toarray()

# %%
acc_rnn = rnn_model.evaluate(X_test, y_test,verbose=0)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc_rnn[0],acc_rnn[1]))
# Out:
# Test set
#   Loss: 11.908
#   Accuracy: 0.110

# %%
acc_rnn = rnn_history.history['accuracy']
val_acc_rnn = rnn_history.history['val_accuracy']
loss_rnn = rnn_history.history['loss']
val_loss_rnn = rnn_history.history['val_loss']

# %%
print(rnn_history)

# %%
# Ploting training and validation metrics as graphs
plt.title('RNN Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc_rnn)),acc_rnn, label='train')
plt.plot(range(len(val_acc_rnn)),val_acc_rnn, label='test')
plt.legend()
plt.show()

plt.title('RNN Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss_rnn)),loss_rnn, label='train')
plt.plot(range(len(val_loss_rnn)),val_loss_rnn, label='test')
plt.legend()
plt.show()

# %% [markdown]
# ###Single layer LSTM

# %%
from keras.models import Sequential, load_model
import pickle
#saving model
single_LSTM_model = load_model('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/single_layer_lstm_model/single_layer_lstm_model.h5')

# Load the history
with open('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/single_layer_lstm_model/single_layer_lstm_history.pkl', 'rb') as f:
    single_layer_lstm_history = pickle.load(f)

# %%
acc_Single_LSTM = single_LSTM_model.evaluate(X_test, y_test,verbose=0)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc_Single_LSTM[0],acc_Single_LSTM[1]))
# Out:
# Test set
#   Loss: 2.347
#   Accuracy: 0.196

# %%
acc_lstm = single_layer_lstm_history.history['accuracy']
val_acc_lstm = single_layer_lstm_history.history['val_accuracy']
loss_lstm = single_layer_lstm_history.history['loss']
val_loss_lstm = single_layer_lstm_history.history['val_loss']

# %%
# Ploting training and validation metrics as graphs
plt.title('Single_LSTM Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc_lstm)),acc_lstm, label='train')
plt.plot(range(len(val_acc_lstm)),val_acc_lstm, label='test')
plt.legend()
plt.show()

plt.title('Single_LSTM Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss_lstm)),loss_lstm, label='train')
plt.plot(range(len(val_loss_lstm)),val_loss_lstm, label='test')
plt.legend()
plt.show()

# %% [markdown]
# ###multi-layer LSTM

# %%
from keras.models import Sequential, load_model
import pickle
#saving model
multi_LSTM_model = load_model('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/multi_layer_lstm_model/multi_layer_lstm_model.h5')

# Load the history
with open('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/multi_layer_lstm_model/multi_layer_lstm_history.pkl', 'rb') as f:
    multi_layer_lstm_history = pickle.load(f)

# %%
acc_multi_LSTM = multi_LSTM_model.evaluate(X_test, y_test,verbose=0)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc_multi_LSTM[0],acc_multi_LSTM[1]))
# Out:
# Test set
#   Loss: 2.342
#   Accuracy: 0.196

# %%
acc_lstm = multi_layer_lstm_history.history['accuracy']
val_acc_lstm = multi_layer_lstm_history.history['val_accuracy']
loss_lstm = multi_layer_lstm_history.history['loss']
val_loss_lstm = multi_layer_lstm_history.history['val_loss']

# %%
# Ploting training and validation metrics as graphs
plt.title('Multi_LSTM Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc_lstm)),acc_lstm, label='train')
plt.plot(range(len(val_acc_lstm)),val_acc_lstm, label='test')
plt.legend()
plt.show()

plt.title('Multi_LSTM Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss_lstm)),loss_lstm, label='train')
plt.plot(range(len(val_loss_lstm)),val_loss_lstm, label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### CNN

# %%
# Load the test dataset
data = np.load('/content/drive/MyDrive/original_dataset/Task_1_model_weights/cnn_lstm_train_and_test_data/train_and_test_data.npz', allow_pickle = True)

# Get the arrays from the loaded data
X_test = data['X_test']
y_test = data['y_test']

# %%
from keras.layers import Conv1D, GlobalMaxPooling1D

# %%
from keras.models import Sequential, load_model
import pickle

# %%
# Save the trained models
cnn_model= load_model('/content/drive/MyDrive/original_dataset/Task_1_model_weights/cnn_model/cnn_model.h5')

# %%
#Saving model history in pickle format
with open('/content/drive/MyDrive/original_dataset/Task_1_model_weights/cnn_model/cnn_history.pkl', 'rb') as f:
    cnn_history= pickle.load(f)

# %%
acc_cnn = cnn_model.evaluate(X_test, y_test,verbose=0)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc_cnn[0],acc_cnn[1]))
# Out:
# Test set
#   Loss: 2.889
#   Accuracy: 0.196

# %%
acc_cnn = cnn_history.history['accuracy']
val_acc_cnn = cnn_history.history['val_accuracy']
loss_cnn = cnn_history.history['loss']
val_loss_cnn = cnn_history.history['val_loss']

# %%
# Ploting training and validation metrics as graphs
plt.title('CNN Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc_cnn)),acc_cnn, label='train')
plt.plot(range(len(val_acc_cnn)),val_acc_cnn, label='test')
plt.legend()
plt.show()

plt.title('CNN Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss_cnn)),loss_cnn, label='train')
plt.plot(range(len(val_loss_cnn)),val_loss_cnn, label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### CNN as an Additional Layer Before LSTM

# %%
#saving model
cnn_lstm_model=load_model('/content/drive/MyDrive/original_dataset/Task_1_model_weights/cnn_lstm_model/cnn_lstm_model.h5')

# %%
from keras.models import Sequential, load_model
import pickle

with open('/content/drive/MyDrive/original_dataset/Task_1_model_weights/cnn_lstm_model/cnn_lstm_model.pkl', 'rb') as f:
    cnn_lstm_history= pickle.load(f)

# %%
acc_cnn_lstm = cnn_lstm_model.evaluate(X_test, y_test,verbose=0)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc_cnn_lstm[0],acc_cnn_lstm[1]))
# Out:
# Test set
#   Loss: 3.057
#   Accuracy: 0.196

# %%
acc_cnn_lstm = cnn_lstm_history.history['accuracy']
val_acc_cnn_lstm = cnn_lstm_history.history['val_accuracy']
loss_cnn_lstm = cnn_lstm_history.history['loss']
val_loss_cnn_lstm = cnn_lstm_history.history['val_loss']

# %%
# Ploting training and validation metrics as graphs
plt.title('CNN_LSTM Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc_cnn_lstm)),acc_cnn_lstm, label='train')
plt.plot(range(len(val_acc_cnn_lstm)),val_acc_cnn_lstm, label='test')
plt.legend()
plt.show()

plt.title('CNN_LSTM Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss_cnn_lstm)),loss_cnn_lstm, label='train')
plt.plot(range(len(val_loss_cnn_lstm)),val_loss_cnn_lstm, label='test')
plt.legend()
plt.show()

# %% [markdown]
# ## Embeddings

# %% [markdown]
# ###SimpleRNN_with pre-trained embedding

# %%
acc_rnn_pre_trained = simpleRNN_glove_model.evaluate(X_test, y_test,verbose=0)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc_rnn_pre_trained[0],acc_rnn_pre_trained[1]))
# Out:
# Test set
#   Loss: 2.982
#   Accuracy: 0.196

# %%
acc_rnn = glove_rnn_history.history['accuracy']
val_acc_rnn = glove_rnn_history.history['val_accuracy']
loss_rnn = glove_rnn_history.history['loss']
val_loss_rnn = glove_rnn_history.history['val_loss']

# %%
# Ploting training and validation metrics as graphs
plt.title('RNN_Glove Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc_rnn)),acc_rnn, label='train')
plt.plot(range(len(val_acc_rnn)),val_acc_rnn, label='test')
plt.legend()
plt.show()

plt.title('RNN_Glove Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss_rnn)),loss_rnn, label='train')
plt.plot(range(len(val_loss_rnn)),val_loss_rnn, label='test')
plt.legend()
plt.show()

# %% [markdown]
# ###Single_LSTM_with pre-trained embedding

# %%
acc_Single_LSTM_pre_trained = glove_single_layer_lstm_model.evaluate(X_test, y_test,verbose=0)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc_Single_LSTM_pre_trained[0],acc_Single_LSTM_pre_trained[1]))
# Out:
# Test set
#   Loss: 5.468
#   Accuracy: 0.152

# %%
acc_lstm = glove_single_layer_lstm_history.history['accuracy']
val_acc_lstm = glove_single_layer_lstm_history.history['val_accuracy']
loss_lstm = glove_single_layer_lstm_history.history['loss']
val_loss_lstm = glove_single_layer_lstm_history.history['val_loss']

# %%
# Ploting training and validation metrics as graphs
plt.title('Single_LSTM_glove Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc_lstm)),acc_lstm, label='train')
plt.plot(range(len(val_acc_lstm)),val_acc_lstm, label='test')
plt.legend()
plt.show()

plt.title('Single_LSTM_glove Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss_lstm)),loss_lstm, label='train')
plt.plot(range(len(val_loss_lstm)),val_loss_lstm, label='test')
plt.legend()
plt.show()

# %% [markdown]
# ###Multi_LSTM_with pre-trained embedding

# %%
acc_multi_LSTM_pre_trained = glove_multi_layer_lstm_model.evaluate(X_test, y_test,verbose=0)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc_multi_LSTM_pre_trained[0],acc_multi_LSTM_pre_trained[1]))
# Out:
# Test set
#   Loss: 4.122
#   Accuracy: 0.196

# %%
acc_lstm = glove_multi_layer_lstm_history.history['accuracy']
val_acc_lstm = glove_multi_layer_lstm_history.history['val_accuracy']
loss_lstm = glove_multi_layer_lstm_history.history['loss']
val_loss_lstm = glove_multi_layer_lstm_history.history['val_loss']

# %%
# Ploting training and validation metrics as graphs
plt.title('Multi_LSTM_Glove Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc_lstm)),acc_lstm, label='train')
plt.plot(range(len(val_acc_lstm)),val_acc_lstm, label='test')
plt.legend()
plt.show()

plt.title('Multi_LSTM_Glove Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss_lstm)),loss_lstm, label='train')
plt.plot(range(len(val_loss_lstm)),val_loss_lstm, label='test')
plt.legend()
plt.show()

# %%
#saving model
simpleRNN_glove_model= load_model('/content/drive/MyDrive/original_dataset/Glove_model_weights/simpleRNN_glove_model/simpleRNN_glove_model.h5')

glove_single_layer_lstm_model= load_model('/content/drive/MyDrive/original_dataset/Glove_model_weights/single_layer_lstm_model/glove_single_layer_lstm_model.h5')
glove_multi_layer_lstm_model= load_model('/content/drive/MyDrive/original_dataset/Glove_model_weights/multi_layer_lstm_model/glove_multi_layer_lstm_model.h5')

# %%
from keras.models import Sequential, load_model
import pickle

with open('/content/drive/MyDrive/original_dataset/Glove_model_weights/simpleRNN_glove_model/glove_rnn_history.pkl', 'rb') as f:
  glove_rnn_history= pickle.load(f)
with open('/content/drive/MyDrive/original_dataset/Glove_model_weights/single_layer_lstm_model/glove_single_layer_lstm_history.pkl', 'rb') as f:
  glove_single_layer_lstm_history= pickle.load(f)

with open('/content/drive/MyDrive/original_dataset/Glove_model_weights/multi_layer_lstm_model/glove_multi_layer_lstm_history.pkl', 'rb') as f:
  glove_multi_layer_lstm_history= pickle.load(f)

# %% [markdown]
# ### CNN Pre-trained embeddings

# %%
#saving model
#simpleRNN_glove_model.save('/content/drive/MyDrive/original_dataset/Glove_model_weights/simpleRNN_glove_model/simpleRNN_glove_model.h5')

glove_cnn_model=load_model('/content/drive/MyDrive/original_dataset/Glove_model_weights/glove_cnn_model/glove_cnn_model.h5')

# %%
from keras.models import Sequential, load_model
import pickle
#Saving the models history in pickle format

#with open('/content/drive/MyDrive/original_dataset/Glove_model_weights/simpleRNN_glove_model/glove_rnn_history.pkl', 'wb') as f:
#    pickle.dump(glove_rnn_history, f)

with open('/content/drive/MyDrive/original_dataset/Glove_model_weights/glove_cnn_model/glove_cnn_model_history.pkl', 'rb') as f:
    glove_cnn_model_history= pickle.load(f)

# %%
glove_cnn_pre_trained = glove_cnn_model.evaluate(X_test, y_test,verbose=0)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(glove_cnn_pre_trained[0],glove_cnn_pre_trained[1]))
# Out:
# Test set
#   Loss: 3.099
#   Accuracy: 0.196

# %%
acc_cnn_glove = glove_cnn_model_history.history['accuracy']
val_acc_cnn_glove = glove_cnn_model_history.history['val_accuracy']
loss_cnn_glove = glove_cnn_model_history.history['loss']
val_loss_cnn_glove = glove_cnn_model_history.history['val_loss']

# %%
# Ploting training and validation metrics as graphs
plt.title('CNN_Glove Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc_cnn_glove)),acc_cnn_glove, label='train')
plt.plot(range(len(val_acc_cnn_glove)),val_acc_cnn_glove, label='test')
plt.legend()
plt.show()

plt.title('CNN_Glove Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss_cnn_glove)),loss_cnn_glove, label='train')
plt.plot(range(len(val_loss_cnn_glove)),val_loss_cnn_glove, label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### CNN as an Additional Layer Before LSTM with pre-trained embeddings

# %%
glove_cnn_lstm_model=load_model('/content/drive/MyDrive/original_dataset/Glove_model_weights/glove_cnn_lstm_model/glove_cnn_lstm_model.h5')

# %%
with open('/content/drive/MyDrive/original_dataset/Glove_model_weights/glove_cnn_lstm_model/glove_cnn_lstm_model_history.pkl', 'rb') as f:
    glove_cnn_lstm_model_history= pickle.load(f)

# %%
acc_cnn_lstm_pre_trained = glove_cnn_lstm_model.evaluate(X_test, y_test,verbose=0)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc_cnn_lstm_pre_trained[0],acc_cnn_lstm_pre_trained[1]))
# Out:
# Test set
#   Loss: 3.065
#   Accuracy: 0.196

# %%
acc_cnn_lstm_glove = glove_cnn_lstm_model_history.history['accuracy']
val_acc_cnn_lstm_glove = glove_cnn_lstm_model_history.history['val_accuracy']
loss_cnn_lstm_glove = glove_cnn_lstm_model_history.history['loss']
val_loss_cnn_lstm_glove = glove_cnn_lstm_model_history.history['val_loss']

# %%
# Ploting training and validation metrics as graphs
plt.title('CNN_LSTM_Glove Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(range(len(acc_cnn_lstm_glove)),acc_cnn_lstm_glove, label='train')
plt.plot(range(len(val_acc_cnn_lstm_glove)),val_acc_cnn_lstm_glove, label='test')
plt.legend()
plt.show()

plt.title('CNN_LSTM_Glove Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(range(len(loss_cnn_lstm_glove)),loss_cnn_lstm_glove, label='train')
plt.plot(range(len(val_loss_cnn_lstm_glove)),val_loss_cnn_lstm_glove, label='test')
plt.legend()
plt.show()

# %% [markdown]
# # Deep Learning Assignment 1 Demo Notebook Part 2

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Import Libararies and Mount Google Drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Aug 29 10:22:06 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   76C    P0    30W /  70W |   4861MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import gdown
import os,glob
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import ast
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import Concatenate, Dense, LSTM, Input,GRU, concatenate,Dropout,LeakyReLU,SimpleRNN,Reshape
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Input,Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import one_hot
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Flatten
from keras.models import Model
import joblib
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from tensorflow.keras.layers import LSTM, BatchNormalization, LeakyReLU, Flatten, Dense
from tensorflow.keras.models import Sequential
from keras.layers import Conv1D, GlobalMaxPooling1D

# %%
#checking weather GPU avaliable or not
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
data_url = "https://drive.google.com/drive/folders/1mrXxH6cFy3yUFYsXoYHLhNI0QevCvpn4?usp=sharing"
gdown.download_folder (data_url, quiet=True, use_cookies=False)
# Out:
# Access denied with the following error:
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1-K_Xr6e8PNBryY1zbJ6m3wCOFYpq_prY

# %% [markdown]
# ### Train Data Preprocessing

# %%
#Loading data
df_full_train = pd.read_csv("/content/original_dataset/train.csv")

# %%
df_full_train.head()
# Out:
#       Artist                     Song Genre Language  \
# 0  12 stones            world so cold  Rock       en
# 1  12 stones                   broken  Rock       en
# 2  12 stones             3 leaf loser  Rock       en
# 3  12 stones  anthem for the underdog  Rock       en
# 4  12 stones               adrenaline  Rock       en
#
#                                               Lyrics
# 0  It starts with pain, followed by hate\nFueled ...
# 1  Freedom!\nAlone again again alone\nPatiently w...
# 2  Biting the hand that feeds you, lying to the v...
# 3  You say you know just who I am\nBut you can't ...
# 4  My heart is beating faster can't control these...

# %%
### Test Data Preprocessing

# %%
# Loading the separate test dataset
df_full_test = pd.read_csv("/content/original_dataset/test.csv")

# %%
df_full_test.head()
# Out:
#                    Song  Song year                   Artist    Genre  \
# 0         craftsmanship       2005                  buck-65  Hip-Hop
# 1           come-on-out       2012               the-elwins    Indie
# 2                  riot       2013  bullet-for-my-valentine    Metal
# 3  that-s-what-girls-do       2007             dream-street      Pop
# 4   believe-in-a-dollar       2012                  cassidy  Hip-Hop
#
#                                               Lyrics  Track_id
# 0  Most folks spend their days daydreaming of fin...      8294
# 1  Take your cold hands and put them on my face\n...     21621
# 2  Are you ready it's time for war\nWe'll break d...      3301
# 3  You ask me why I change the color of my hair\n...      2773
# 4  Do you believe in magic in a young girl's hear...     16797

# %%
# Combine the train and test datasets along the rows (axis=0)
combined_df = pd.concat([df_full_train, df_full_test], axis=0, ignore_index=True)

# Display the combined dataframe
print(combined_df)
# Out:
#                  Artist                     Song    Genre Language  \
# 0             12 stones            world so cold     Rock       en
# 1             12 stones                   broken     Rock       en
# 2             12 stones             3 leaf loser     Rock       en
# 3             12 stones  anthem for the underdog     Rock       en
# 4             12 stones               adrenaline     Rock       en
# ...                 ...                      ...      ...      ...
# 298113  amanda-marshall      too-little-too-late     Rock      NaN
# 298114  aurora-borealis                berserker    Metal      NaN
# 298115           dr-dre      natural-born-killaz  Hip-Hop      NaN
# 298116    chris-cornell               wide-awake     Rock      NaN
# 298117        the-coral                god-knows     Rock      NaN
#
#                                                    Lyrics  Song year  Track_id
# 0       It starts with pain, followed by hate\nFueled ...        NaN       NaN
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298118 entries, 0 to 298117
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Artist     298118 non-null  object
#  1   Song       298117 non-null  object
#  2   Genre      298118 non-null  object
#  3   Language   290179 non-null  object
#  4   Lyrics     298083 non-null  object
#  5   Song year  7935 non-null    float64
#  6   Track_id   7935 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 15.9+ MB

# %%
#we have two columns which are having less sample comapred to the total samples
#i.e: "Song Year" and "Track id" columns

# %%
#checking wether the dataset had null values in the combined dataset

combined_df.isnull().sum()
# Out:
# Artist            0
# Song              1
# Genre             0
# Language       7939
# Lyrics           35
# Song year    290183
# Track_id     290183
# dtype: int64

# %%
#we have some null values is the dataset which are song year, Track_id
#so we are going to drop the columns from combined dataset

# %%
# Droping the specified columns from the combined dataframe
columns_to_drop = ["Song year", "Track_id", "Language"]
combined_df = combined_df.drop(columns=columns_to_drop)

# Display the updated combined dataframe
print(combined_df)
# Out:
#                  Artist                     Song    Genre  \
# 0             12 stones            world so cold     Rock
# 1             12 stones                   broken     Rock
# 2             12 stones             3 leaf loser     Rock
# 3             12 stones  anthem for the underdog     Rock
# 4             12 stones               adrenaline     Rock
# ...                 ...                      ...      ...
# 298113  amanda-marshall      too-little-too-late     Rock
# 298114  aurora-borealis                berserker    Metal
# 298115           dr-dre      natural-born-killaz  Hip-Hop
# 298116    chris-cornell               wide-awake     Rock
# 298117        the-coral                god-knows     Rock
#
#                                                    Lyrics
# 0       It starts with pain, followed by hate\nFueled ...
# 1       Freedom!\nAlone again again alone\nPatiently w...
# 2       Biting the hand that feeds you, lying to the v...
# ...

# %%
combined_df.isnull().sum()
# Out:
# Artist     0
# Song       1
# Genre      0
# Lyrics    35
# dtype: int64

# %%
#droping null values samples from the dataset
combined_df = combined_df.dropna()

# %%
# Saving the combined dataset to a CSV file after cleaning the dataset
combined_df.to_csv("/content/drive/MyDrive/Data_Saved/combined_dataset.csv", index=False)

# %%
# Grouping data by Artist and calculate song count
artist_song_count = combined_df.groupby("Artist")["Song"].count().reset_index()

# %%
#Sorting artists by song count in descending order
sorted_artists = artist_song_count.sort_values(by="Song", ascending=False)

# %%
#Selecting top 10 artists
top_10_artists = sorted_artists.head(10)

# %%
top_10_artists
# Out:
#                    Artist  Song
# 6619        elvis presley  1611
# 4019          chris brown  1239
# 6614       elvis costello   923
# 6570      ella fitzgerald   874
# 12588  the rolling stones   820
# 2023             bee gees   811
# 8058                 glee   765
# 2234              beyonce   752
# 1751         bad religion   751
# 6606           elton john   728

# %%
#Creating a new dataset for top 10 artists
top_10_artist_data = combined_df[combined_df["Artist"].isin(top_10_artists["Artist"])]

# %%
# Displaying the new dataset for top 10 artists
print(top_10_artist_data)
# Out:
#                  Artist                     Song    Genre  \
# 3791       bad religion           american jesus      Pop
# 3792       bad religion                 infected      Pop
# 3793       bad religion                   a walk      Pop
# 3794       bad religion                   sorrow      Pop
# 3795       bad religion                      you      Pop
# ...                 ...                      ...      ...
# 289878  ella fitzgerald  too marvelous for words     Jazz
# 289948      chris brown             i get around  Hip-Hop
# 290027  ella fitzgerald      ev rything i ve got     Jazz
# 291757          beyonce                   6-inch      Pop
# 297614          beyonce             sweet-dreams      Pop
#
#                                                    Lyrics
# 3791    I don't need to be a global citizen,\n'Cuz I'm...
# 3792    Infected\nNow here I go,\nHope I don't break d...
# 3793    I'm going for a walk\nnot the after dinner kin...
# ...

# %%
# Saving the combined dataset to a CSV file after cleaning the dataset
top_10_artist_data.to_csv("/content/drive/MyDrive/Data_Saved/top_10_artist_dataset.csv", index=False)

# %%
top_10_artist_data
# Out:
#                  Artist                     Song    Genre  \
# 3791       bad religion           american jesus      Pop
# 3792       bad religion                 infected      Pop
# 3793       bad religion                   a walk      Pop
# 3794       bad religion                   sorrow      Pop
# 3795       bad religion                      you      Pop
# ...                 ...                      ...      ...
# 289878  ella fitzgerald  too marvelous for words     Jazz
# 289948      chris brown             i get around  Hip-Hop
# 290027  ella fitzgerald      ev rything i ve got     Jazz
# 291757          beyonce                   6-inch      Pop
# 297614          beyonce             sweet-dreams      Pop
#
#                                                    Lyrics
# 3791    I don't need to be a global citizen,\n'Cuz I'm...
# 3792    Infected\nNow here I go,\nHope I don't break d...
# 3793    I'm going for a walk\nnot the after dinner kin...
# ...

# %%
top_10_artist_data.isnull().sum()
# Out:
# Artist    0
# Song      0
# Genre     0
# Lyrics    0
# dtype: int64

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense

from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt

# %%
# Spliting data into train, validation, and no testset in this section
#dividing data into 90% and 10% testset

train_data, val_data = train_test_split(top_10_artist_data, test_size=0.1, random_state=42, stratify =top_10_artist_data["Artist"])

# %%
# Converting artist labels to one-hot encoding as it is a multiclass classification

#Converting first artist labels to integers using label encoding
label_encoder = LabelEncoder()
train_data["Artist"] = label_encoder.fit_transform(train_data["Artist"])
val_data["Artist"] = label_encoder.transform(val_data["Artist"])

# %%
#Total number of classes
num_classes = len(label_encoder.classes_)

# %%
# Creating TF-IDF text vectorizer

#When we run population data we can keep 10000 or more
#For now we are keeping 5000 for model building and computational purpose

max_features = 5000  # we can adjust as needed

tfidf_vectorizer = TfidfVectorizer(max_features=max_features)

# %%
# Fitting and transforming the text data
#training set
X_train_tfidf = tfidf_vectorizer.fit_transform(train_data["Lyrics"])
#validation set
X_val_tfidf = tfidf_vectorizer.transform(val_data["Lyrics"])

# %%
# Converting secondly Artist labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(train_data["Artist"], num_classes)
y_val = tf.keras.utils.to_categorical(val_data["Artist"], num_classes)

# %%
# Converting sparse matrices to dense arrays
X_train_tfidf_dense = X_train_tfidf.toarray()
X_val_tfidf_dense = X_val_tfidf.toarray()

# %%
#Data saving for further use in future

np.savez('/content/drive/MyDrive/original_dataset/Task_2_model_weights/top_10_artist_train_test.npz',
         X_train=X_train_tfidf_dense,y_train=y_train, X_val = X_val_tfidf_dense, y_val= y_val)

# %% [markdown]
# ## Models

# %% [markdown]
# ### Multilayer-LSTM

# %%
from keras.models import Sequential, load_model
import pickle
#saving model
multi_LSTM_TL_model = load_model('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/multi_layer_lstm_model/multi_layer_lstm_model.h5')

# Load the history
# with open('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/multi_layer_lstm_model/multi_layer_lstm_history.pkl', 'rb') as f:
#     multi_layer_lstm_history = pickle.load(f)

# %%
# Defining early stopping criteria
early_stop = EarlyStopping(monitor='val_loss', patience=2)


# Train the models
batch_size = 32
epochs = 10

print("Printing transfer learning multilayer layer lstm epochs")
multi_layer_lstm_tl_history = multi_LSTM_TL_model.fit(X_train_tfidf_dense, y_train,
                                                      validation_data=(X_val_tfidf_dense, y_val), epochs=epochs, batch_size=batch_size, callbacks=[early_stop])
# Out:
# Printing transfer learning multilayer layer lstm epochs
# Epoch 1/10
# 261/261 [==============================] - 111s 410ms/step - loss: 2.3020 - accuracy: 0.1658 - val_loss: 2.2748 - val_accuracy: 0.1735
# Epoch 2/10
# 261/261 [==============================] - 106s 406ms/step - loss: 2.2759 - accuracy: 0.1694 - val_loss: 2.2763 - val_accuracy: 0.1735
# Epoch 3/10
# 261/261 [==============================] - 106s 406ms/step - loss: 2.2753 - accuracy: 0.1706 - val_loss: 2.2766 - val_accuracy: 0.1735

# %%
#Model saving
multi_LSTM_TL_model.save('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/multi_LSTM_TL_model/multi_LSTM_TL_model.h5')

# %%
from keras.models import Sequential, load_model
import pickle
#saving model
with open('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/multi_LSTM_TL_model/multi_layer_lstm_tl_history.pkl', 'wb') as f:
    pickle.dump(multi_layer_lstm_tl_history, f)

# %%
# Plot training and validation accuracy as graphs
def plot_history(history, model_name):
    plt.plot(history.history['accuracy'], label=f'{model_name} accuracy')
    plt.plot(history.history['val_accuracy'], label = f'{model_name} val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1])
    plt.legend(loc='lower right')
    plt.title(f'{model_name} Training and Validation Accuracy')
    plt.show()

plot_history(multi_layer_lstm_tl_history, 'Multi-Layer LSTM')

# %% [markdown]
# ### CNN

# %%
from keras.models import Sequential, load_model
import pickle
#saving model
CNN_TL_model = load_model('/content/drive/MyDrive/original_dataset/Task_1_model_weights/cnn_model/cnn_model.h5')

# Load the history
with open('/content/drive/MyDrive/original_dataset/Task_1_model_weights/cnn_model/cnn_history.pkl', 'rb') as f:
    cnn_history = pickle.load(f)

# %%
# Defining early stopping criteria
early_stop = EarlyStopping(monitor='val_loss', patience=2)


# Train the models
batch_size = 32
epochs = 10

print("Printing transfer learning multilayer layer lstm epochs")
cnn_tl_history = CNN_TL_model.fit(X_train_tfidf_dense, y_train,
                                                      validation_data=(X_val_tfidf_dense, y_val), epochs=epochs, batch_size=batch_size, callbacks=[early_stop])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c5d23d2b736a> in <cell line: 2>()
#       1 # Defining early stopping criteria
# ----> 2 early_stop = EarlyStopping(monitor='val_loss', patience=2)
#       3
#       4
#       5 # Train the models
#
# NameError: name 'EarlyStopping' is not defined

# %%
#Model saving
CNN_TL_model.save('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/CNN_TL_model/CNN_TL_model.h5')

# %%
from keras.models import Sequential, load_model
import pickle
#saving model
with open('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/CNN_TL_model/cnn_tl_history.pkl', 'wb') as f:
    pickle.dump(cnn_tl_history, f)

# %%
# Plot training and validation accuracy as graphs
def plot_history(history, model_name):
    plt.plot(history.history['accuracy'], label=f'{model_name} accuracy')
    plt.plot(history.history['val_accuracy'], label = f'{model_name} val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1])
    plt.legend(loc='lower right')
    plt.title(f'{model_name} Training and Validation Accuracy')
    plt.show()

plot_history(cnn_tl_history, 'CNN')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1cb985283739> in <cell line: 12>()
#      10     plt.show()
#      11
# ---> 12 plot_history(cnn_tl_history, 'CNN')
#
# NameError: name 'cnn_tl_history' is not defined

# %% [markdown]
# ### Multilayer LSTM Artist Prediction

# %%
# Building and compile the models

def build_multi_layer_lstm_model():
    model_lstm = Sequential()
    model_lstm.add(Embedding(input_dim=max_features, output_dim=128, input_length=X_train_tfidf.shape[1]))
    model_lstm.add(LSTM(128, return_sequences=True))
    model_lstm.add(Dropout(0.5))  # Add dropout layer with a dropout rate of 0.5
    model_lstm.add(LSTM(128, return_sequences=True))
    model_lstm.add(Dropout(0.5))  # Add dropout layer with a dropout rate of 0.5
    model_lstm.add(LSTM(128, return_sequences=False))
    model_lstm.add(Dropout(0.5))  # Add dropout layer with a dropout rate of 0.5
    model_lstm.add(BatchNormalization())
    model_lstm.add(LeakyReLU(alpha=0.01))
    model_lstm.add(Flatten())
    model_lstm.add(Dense(num_classes, activation='softmax'))
    print(model_lstm.summary())
    return model_lstm

# %%
# Building and compiling the models within the strategy scope and using categorical_crossentropy as loss fucntion
multi_layer_lstm_artist_model = build_multi_layer_lstm_model()
multi_layer_lstm_artist_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 5000, 128)         640000
#
#  lstm (LSTM)                 (None, 5000, 128)         131584
#
#  dropout (Dropout)           (None, 5000, 128)         0
#
#  lstm_1 (LSTM)               (None, 5000, 128)         131584
#
#  dropout_1 (Dropout)         (None, 5000, 128)         0
#
#  lstm_2 (LSTM)               (None, 128)               131584
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 128)               0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 10)                1290
#
# ...
# Total params: 1,036,554
# Trainable params: 1,036,298
# Non-trainable params: 256
# ...

# %%
# Defining early stopping criteria
early_stop = EarlyStopping(monitor='val_loss', patience=2)


# Train the models
batch_size = 32
epochs = 10

print("Printing multilayer layer lstm epochs")
multi_layer_lstm_artist_history = multi_layer_lstm_artist_model.fit(X_train_tfidf_dense, y_train,
                                                      validation_data=(X_val_tfidf_dense, y_val), epochs=epochs, batch_size=batch_size, callbacks=[early_stop])
# Out:
# Printing multilayer layer lstm epochs
# Epoch 1/10
# 261/261 [==============================] - 113s 411ms/step - loss: 2.3214 - accuracy: 0.1434 - val_loss: 2.2938 - val_accuracy: 0.1735
# Epoch 2/10
# 261/261 [==============================] - 106s 407ms/step - loss: 2.2946 - accuracy: 0.1628 - val_loss: 2.2834 - val_accuracy: 0.1735
# Epoch 3/10
# 261/261 [==============================] - 106s 408ms/step - loss: 2.2841 - accuracy: 0.1659 - val_loss: 2.2800 - val_accuracy: 0.1336
# Epoch 4/10
# 261/261 [==============================] - 106s 408ms/step - loss: 2.2789 - accuracy: 0.1693 - val_loss: 2.2788 - val_accuracy: 0.1735
# Epoch 5/10
# 261/261 [==============================] - 106s 406ms/step - loss: 2.2807 - accuracy: 0.1689 - val_loss: 2.2822 - val_accuracy: 0.1735
# Epoch 6/10
# 261/261 [==============================] - 106s 406ms/step - loss: 2.2760 - accuracy: 0.1697 - val_loss: 2.2690 - val_accuracy: 0.1735
# Epoch 7/10
# ...

# %%
#Model saving
multi_layer_lstm_artist_model.save('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/multi_layer_lstm_artist_model/multi_layer_lstm_artist_model.h5')

# %%
from keras.models import Sequential, load_model
import pickle
#saving model
with open('/content/drive/MyDrive/original_dataset/LSTM_Weights_task_1/multi_layer_lstm_artist_model/multi_layer_lstm_history.pkl', 'wb') as f:
    pickle.dump(multi_layer_lstm_tl_history, f)

# %% [markdown]
# Ploting

# %%
# Plot training and validation accuracy as graphs
def plot_history(history, model_name):
    plt.plot(history.history['accuracy'], label=f'{model_name} accuracy')
    plt.plot(history.history['val_accuracy'], label = f'{model_name} val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1])
    plt.legend(loc='lower right')
    plt.title(f'{model_name} Training and Validation Accuracy')
    plt.show()

plot_history(multi_layer_lstm_tl_history, 'Multi-Layer LSTM')

# %% [markdown]
# ### CNN Artist Prediction

# %%
# Defining the CNN model here we are using specially Conv1D

def build_cnn_model():
    model_cnn = Sequential()
    model_cnn.add(Embedding(input_dim=max_features, output_dim=128, input_length=X_train_tfidf.shape[1]))
    model_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model_cnn.add(Conv1D(filters=64, kernel_size=4, activation='relu'))
    model_cnn.add(Conv1D(filters=64, kernel_size=5, activation='relu'))
    model_cnn.add(GlobalMaxPooling1D())
    model_cnn.add(Dense(128, activation='relu'))
    model_cnn.add(Dense(num_classes, activation='softmax'))
    #model_cnn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model_cnn

# %%
#with strategy.scope():

cnn_artist_model = build_cnn_model()
cnn_artist_model.compile(optimizer = "adam", loss="categorical_crossentropy", metrics=["accuracy"])

cnn_artist_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 5000, 128)         640000
#
#  conv1d (Conv1D)             (None, 4998, 64)          24640
#
#  conv1d_1 (Conv1D)           (None, 4995, 64)          16448
#
#  conv1d_2 (Conv1D)           (None, 4991, 64)          20544
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 10)                1290
#
# ...
# Total params: 711,242
# Trainable params: 711,242
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Defining early stopping criteria
early_stop = EarlyStopping(monitor='val_loss', patience=2)

# Training the models with dense arrays
# Train the models using distributed training (with larger batch size)
batch_size = 32  # Adjust as needed
epochs = 10  # Adjust as needed
# Building and compiling the models within the strategy scope and using categorical_crossentropy as loss fucntion

print("Printing CNN Epochs")
cnn_artist_history = cnn_artist_model.fit(X_train_tfidf_dense, y_train, validation_data=(X_val_tfidf_dense, y_val), epochs=epochs, batch_size=batch_size, callbacks=[early_stop])
# Out:
# Printing CNN Epochs
# Epoch 1/10
# 261/261 [==============================] - 12s 40ms/step - loss: 2.2714 - accuracy: 0.1729 - val_loss: 2.2746 - val_accuracy: 0.1735
# Epoch 2/10
# 261/261 [==============================] - 10s 39ms/step - loss: 2.2693 - accuracy: 0.1737 - val_loss: 2.2655 - val_accuracy: 0.1735
# Epoch 3/10
# 261/261 [==============================] - 10s 39ms/step - loss: 2.2673 - accuracy: 0.1736 - val_loss: 2.2653 - val_accuracy: 0.1746
# Epoch 4/10
# 261/261 [==============================] - 10s 38ms/step - loss: 2.2663 - accuracy: 0.1741 - val_loss: 2.2645 - val_accuracy: 0.1746
# Epoch 5/10
# 261/261 [==============================] - 10s 38ms/step - loss: 2.2658 - accuracy: 0.1742 - val_loss: 2.2650 - val_accuracy: 0.1746
# Epoch 6/10
# 261/261 [==============================] - 10s 38ms/step - loss: 2.2659 - accuracy: 0.1742 - val_loss: 2.2644 - val_accuracy: 0.1746
# Epoch 7/10
# ...

# %%
# Save the trained models
cnn_artist_model.save('/content/drive/MyDrive/original_dataset/Task_1_model_weights/cnn_artist_model/cnn_artist_model.h5')

# %%
from keras.models import Sequential, load_model
import pickle
#Saving model history in pickle format
with open('/content/drive/MyDrive/original_dataset/Task_1_model_weights/cnn_artist_model/cnn_artist_history.pkl', 'wb') as f:
    pickle.dump(cnn_tl_history, f)

# %%
# Ploting training and validation metrics as graphs
def plot_history(history, model_name):
    plt.plot(history.history['accuracy'], label=f'{model_name} accuracy')
    plt.plot(history.history['val_accuracy'], label = f'{model_name} val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1])
    plt.legend(loc='lower right')
    plt.title(f'{model_name} Training and Validation Accuracy')
    plt.show()

plot_history(cnn_artist_history, 'CNN')

# %% [markdown]
# # Part 3 Lyrics Generation.

# %% [markdown]
# ### Load Libraries

# %%
import gdown
import os,glob
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ### Load Test data and saved Models from the drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
url = "https://drive.google.com/drive/folders/1wl82IEN7A2ujuYAIJHvsoOYvB7l_tHJK?usp=sharing"
gdown.download_folder (url, quiet=True, use_cookies=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-1f3d0e3dac6f> in <cell line: 2>()
#       1 url = "https://drive.google.com/drive/folders/1wl82IEN7A2ujuYAIJHvsoOYvB7l_tHJK?usp=sharing"
# ----> 2 gdown.download_folder (url, quiet=True, use_cookies=False)
#
# /usr/local/lib/python3.10/dist-packages/gdown/download_folder.py in download_folder(url, id, output, quiet, proxy, speed, use_cookies, remaining_ok, verify)
#     301             continue
#     302
# --> 303         filename = download(
#     304             url="https://drive.google.com/uc?id=" + file_id,
#     305             output=file_path,
#
# /usr/local/lib/python3.10/dist-packages/gdown/download.py in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume)
#     153     while True:
#     154         try:
# ...

# %% [markdown]
# ### Test Data Preprocessing

# %%
import pandas as pd

# Load the lyrics dataset
lyrics_data = pd.read_csv("/content/drive/MyDrive/original_dataset/train.csv")  # Replace with the actual dataset path

# %%
# Grouping data by Artist and calculate song count
artist_song_count = lyrics_data.groupby("Artist")["Song"].count().reset_index()

# %%
#Sorting artists by song count in descending order
sorted_artists = artist_song_count.sort_values(by="Song", ascending=False)

# %%
#
top_3_artists = sorted_artists.head(3)

# %%
top_3_artists
# Out:
#               Artist  Song
# 4883   elvis presley  1611
# 2969     chris brown  1239
# 4878  elvis costello   923

# %%
#Creating a new dataset for top 10 artists
top_3_artist_data = lyrics_data[lyrics_data["Artist"].isin(top_3_artists["Artist"])]

# %%
# Displaying the new dataset for top 10 artists
print(top_3_artist_data)
# Out:
#                 Artist                                               Song  \
# 16793   elvis costello                                                she
# 16794   elvis costello                                      sparkling day
# 16795   elvis costello                                             alison
# 16796   elvis costello  (what's so funny 'bout) peace love and underst...
# 16797   elvis costello                                          beautiful
# ...                ...                                                ...
# 289223     chris brown                                            twitter
# 289476     chris brown                                              smash
# 289664   elvis presley                                     echoes of love
# 289790   elvis presley                          he knows just what i need
# 289948     chris brown                                       i get around
#
#           Genre Language                                             Lyrics
# ...

# %%
# Saving the combined dataset to a CSV file after cleaning the dataset
top_3_artist_data.to_csv("/content/drive/MyDrive/Data_Saved/top_3_artist_dataset.csv", index=False)

# %%
top_3_artist_data
# Out:
#                 Artist                                               Song  \
# 16793   elvis costello                                                she
# 16794   elvis costello                                      sparkling day
# 16795   elvis costello                                             alison
# 16796   elvis costello  (what's so funny 'bout) peace love and underst...
# 16797   elvis costello                                          beautiful
# ...                ...                                                ...
# 289223     chris brown                                            twitter
# 289476     chris brown                                              smash
# 289664   elvis presley                                     echoes of love
# 289790   elvis presley                          he knows just what i need
# 289948     chris brown                                       i get around
#
#           Genre Language                                             Lyrics
# ...

# %%
top_3_artist_data.isnull().sum()
# Out:
# Artist      0
# Song        0
# Genre       0
# Language    0
# Lyrics      0
# dtype: int64

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense

from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt

# %%
# Spliting data into train, validation, and no testset in this section
#dividing data into 90% and 10% testset

train_data, val_data = train_test_split(top_3_artist_data, test_size=0.1, random_state=42, stratify =top_3_artist_data["Artist"])

# %%
# Converting artist labels to one-hot encoding as it is a multiclass classification

#Converting first artist labels to integers using label encoding
label_encoder = LabelEncoder()
train_data["Artist"] = label_encoder.fit_transform(train_data["Artist"])
val_data["Artist"] = label_encoder.transform(val_data["Artist"])

# %%
#Total number of classes
num_classes = len(label_encoder.classes_)

# %%
# Creating TF-IDF text vectorizer

#When we run population data we can keep 10000 or more
#For now we are keeping 5000 for model building and computational purpose

max_features = 5000  # we can adjust as needed

tfidf_vectorizer = TfidfVectorizer(max_features=max_features)

# %%
# Fitting and transforming the text data
#training set
X_train_tfidf = tfidf_vectorizer.fit_transform(train_data["Lyrics"])
#validation set
X_val_tfidf = tfidf_vectorizer.transform(val_data["Lyrics"])

# %%
# Converting secondly Artist labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(train_data["Artist"], num_classes)
y_val = tf.keras.utils.to_categorical(val_data["Artist"], num_classes)

# %%
# Converting sparse matrices to dense arrays
X_train_tfidf_dense = X_train_tfidf.toarray()
X_val_tfidf_dense = X_val_tfidf.toarray()

# %%
#Data saving for further use in future

np.savez('/content/drive/MyDrive/original_dataset/Task_2_model_weights/top_3_artist_train_test.npz',
         X_train=X_train_tfidf_dense,y_train=y_train, X_val = X_val_tfidf_dense, y_val= y_val)

# %% [markdown]
# ## MultiLayer Model LSTM

# %%
import gdown
import os,glob
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import ast
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import Concatenate, Dense, LSTM, Input,GRU, concatenate,Dropout,LeakyReLU,SimpleRNN,Reshape
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Input,Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import one_hot
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import Flatten
from keras.models import Model
import joblib
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from tensorflow.keras.layers import SimpleRNN, BatchNormalization, LeakyReLU, Flatten, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, BatchNormalization, LeakyReLU, Flatten, Dense
from tensorflow.keras.models import Sequential

# %%
# Building and compile the models
def build_multi_layer_lstm_model():
    model_lstm = Sequential()
    model_lstm.add(Embedding(input_dim=max_features, output_dim=128, input_length=X_train_tfidf.shape[1]))
    model_lstm.add(LSTM(128, return_sequences=True))
    model_lstm.add(Dropout(0.5))  # Add dropout layer with a dropout rate of 0.5
    model_lstm.add(LSTM(128, return_sequences=True))
    model_lstm.add(Dropout(0.5))  # Add dropout layer with a dropout rate of 0.5
    model_lstm.add(LSTM(128, return_sequences=False))
    model_lstm.add(Dropout(0.5))  # Add dropout layer with a dropout rate of 0.5
    model_lstm.add(BatchNormalization())
    model_lstm.add(LeakyReLU(alpha=0.01))
    model_lstm.add(Flatten())
    model_lstm.add(Dense(num_classes, activation='softmax'))
    print(model_lstm.summary())
    return model_lstm

# %%
# Building and compiling the models within the strategy scope and using categorical_crossentropy as loss fucntion
multi_layer_lstm_gen_model = build_multi_layer_lstm_model()
multi_layer_lstm_gen_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, 5000, 128)         640000
#
#  lstm_6 (LSTM)               (None, 5000, 128)         131584
#
#  dropout_6 (Dropout)         (None, 5000, 128)         0
#
#  lstm_7 (LSTM)               (None, 5000, 128)         131584
#
#  dropout_7 (Dropout)         (None, 5000, 128)         0
#
#  lstm_8 (LSTM)               (None, 128)               131584
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 128)               0
#
#  flatten_2 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 3)                 387
#
# ...
# Total params: 1,035,651
# Trainable params: 1,035,395
# Non-trainable params: 256
# ...

# %%
# Defining early stopping criteria
early_stop = EarlyStopping(monitor='val_loss', patience=2)


# Train the models
batch_size = 32
epochs = 10

print("Printing multilayer layer lstm epochs")

multi_layer_lstm_gen_history = multi_layer_lstm_gen_model.fit(X_train_tfidf_dense, y_train,
                                                      validation_data=(X_val_tfidf_dense, y_val), epochs=epochs, batch_size=batch_size, callbacks=[early_stop])
# Out:
# Printing multilayer layer lstm epochs
# Epoch 1/10
# 107/107 [==============================] - 51s 430ms/step - loss: 1.1423 - accuracy: 0.3747 - val_loss: 1.0973 - val_accuracy: 0.4259
# Epoch 2/10
# 107/107 [==============================] - 44s 415ms/step - loss: 1.1153 - accuracy: 0.3823 - val_loss: 1.0985 - val_accuracy: 0.3280
# Epoch 3/10
# 107/107 [==============================] - 45s 417ms/step - loss: 1.0992 - accuracy: 0.3997 - val_loss: 1.0944 - val_accuracy: 0.4259
# Epoch 4/10
# 107/107 [==============================] - 44s 416ms/step - loss: 1.0989 - accuracy: 0.3862 - val_loss: 1.0839 - val_accuracy: 0.4259
# Epoch 5/10
# 107/107 [==============================] - 45s 417ms/step - loss: 1.0923 - accuracy: 0.4006 - val_loss: 1.0758 - val_accuracy: 0.4259
# Epoch 6/10
# 107/107 [==============================] - 45s 417ms/step - loss: 1.0907 - accuracy: 0.4012 - val_loss: 1.0796 - val_accuracy: 0.4259
# Epoch 7/10
# ...

# %% [markdown]
# Ploting

# %%
# Plot training and validation accuracy as graphs
def plot_history(history, model_name):
    plt.plot(history.history['accuracy'], label=f'{model_name} accuracy')
    plt.plot(history.history['val_accuracy'], label = f'{model_name} val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1])
    plt.legend(loc='lower right')
    plt.title(f'{model_name} Training and Validation Accuracy')
    plt.show()

plot_history(multi_layer_lstm_gen_history, 'Multi-Layer LSTM')

# %%
max_len=5000

# %% [markdown]
# ## Lyrics Generation

# %%
# Generate lyrics using the trained model
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer=Tokenizer()
for genre in ["Rock", "Pop"]:
    seed_text = "The song lyrics is related to the genre of " + genre
    for i in range(10):
        encoded_text = tokenizer.texts_to_sequences([seed_text])[0]
        padded_text = pad_sequences([encoded_text], maxlen=max_len, padding="post")
        prediction = multi_layer_lstm_gen_model.predict(padded_text)[0]
        predicted_word_index = np.argmax(prediction)
        predicted_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted_word_index:
                predicted_word = word
                break
        seed_text += " " + predicted_word
    print("Generated " + genre + " song : " + seed_text)
# Out:
# ...
# 1/1 [==============================] - 0s 138ms/step
# Generated Rock song : The song lyrics is related to the genre of Rock
# ...
# 1/1 [==============================] - 0s 139ms/step
# Generated Pop song : The song lyrics is related to the genre of Pop

# %%
# Generate lyrics using the trained model
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer=Tokenizer()
for artist in ["elvis presley", "chris brown","elvis costello"]:
    seed_text = "The song lyrics is related to the artist of " + artist
    for i in range(10):
        encoded_text = tokenizer.texts_to_sequences([seed_text])[0]
        padded_text = pad_sequences([encoded_text], maxlen=max_len, padding="post")
        prediction = multi_layer_lstm_gen_model.predict(padded_text)[0]
        predicted_word_index = np.argmax(prediction)
        predicted_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted_word_index:
                predicted_word = word
                break
        seed_text += " " + predicted_word
    print("Generated " + artist + " song : " + seed_text)
# Out:
# ...
# 1/1 [==============================] - 0s 160ms/step
# Generated elvis presley song : The song lyrics is related to the artist of elvis presley
# ...
# 1/1 [==============================] - 0s 159ms/step
# Generated chris brown song : The song lyrics is related to the artist of chris brown
# ...
# 1/1 [==============================] - 0s 160ms/step
# Generated elvis costello song : The song lyrics is related to the artist of elvis costello
